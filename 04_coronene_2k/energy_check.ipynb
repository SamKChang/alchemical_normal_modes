# %%
import qctoolkit as qtk
import numpy as np
from glob import glob

# %%
outs = []
for out in sorted(glob("g09_output/coronene-random-02-ccpvdz-00000??.log")):
    outs.append(qtk.QMOut(out, program='gaussian'))

# %%
for out in outs:
    mol = out.molecule.copy()
    mol.rotate(np.pi/2., [0,1,0])
    #mol.rotate(-np.pi/2., [0,0,1])
    
    mol.view2D()

# %%
E0_tot = -920.806635315
E0_ele = -2741.1485245489703

# %%
outs[0].molecule.nuclear_repulsion()
# Out:
# 1820.1573548533775

# %%
outs[0].Et - outs[0].molecule.nuclear_repulsion() - E0_ele
# Out:
# -1.4873900044071888
